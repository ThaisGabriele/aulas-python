# %% [markdown]
# **Exemplos**

# %%
# Verifica se o aluno foi aprovado(nota >= 5.0) ou reprovado (nota < 5.0)

nota = float(input("Digite sua nota: "))

if nota >= 5.0:
  print("Aprovado!")
else:
  print("Reprovado")

# %%
# Verifica se a senha é igual A "admin"

senha = input("Senha: ")

if (senha == "admin"):
  print("Senha correta")
else:
  print("Senha incorreta")

# %%
# módulo datetime para obter valores de data e hora atuais
from datetime import datetime
hoje = datetime.now() #método now

# %%
# Verifica se hoje é seu aniversário


dia = int(input("Digite o dia que você nasceu: "))
mes = int(input("Digite o mes que você nasceu: "))

if (hoje.day == dia and hoje.month == mes):
  print("Feliz aniversário!!!!!!!")
else:
  print("Hoje não é seu aniversário")

# %% [markdown]
# **Exercícios**

# %% [markdown]
# 1 - Faça um programa que verifica se o usuário é maior de idade ou menor de idade.
#
# **EXEMPLO DE ENTRADA**
#
# 17
#
# **EXEMPLO DE SAÍDA**
#
# menor de idade
#
# -----
#
# **EXEMPLO DE ENTRADA**
#
# 27
#
# **EXEMPLO DE SAÍDA**
#
# maior de idade

# %%
idade = int(input("Digite sua idade: "))

if idade < 18:
  print("menor de idade")
else:
  print("maior de idade")
# Out:
# Digite sua idade: 18
# maior de idade

# %% [markdown]
# 2 - Faça um programa que verifica se um número dado pelo usuário é maior que 0 ou menor que 0
#
# **ENTRADA**
#
# 20
#
# **SAÍDA**
#
# é maior
#
# ----
#
# **ENTRADA**
#
# -1
#
# **SAÍDA**
#
# é menor

# %%
numero = int(input("Digite seu número: "))

if numero > 0:
  print("maior que zero")
elif numero == 0:
  print("igual a zero")
else:
  print("menor que zero")
# Out:
# Digite seu número: -2
# menor que zero

# %% [markdown]
# 3 - Faça um programa que tem como entrada notas de três alunos e verifica se a média das notas desses alunos é maior que 5.0 ou menor que 5.0.
#
# **EXEMPLO DE ENTRADA**
#
# 10.0
#
# 5.0
#
# 7.0
#
#
# **EXEMPLO DE SAÍDA**
#
# é maior
#
# -------
#
# **EXEMPLO DE ENTRADA**
#
# 4.0
#
# 3.0
#
# 2.0
#
#
# **EXEMPLO DE SAÍDA**
#
# é menor

# %%
soma = nota = qtd = media = 0

while qtd < 3:
  nota = float(input("Digite a nota: ")
  if nota < 5:
     print("Reprovado")
  else:
     print("Aprovado")
  qtd +=
  soma = soma + nota
  media = soma / 3
# Out:
#   File "<ipython-input-13-0c8a5ab41c8a>", line 5
#     if nota < 5 :
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Exercícios de Condicionais Aninhadas -  elif**

# %% [markdown]
# **Exemplos com elif**

# %%
# Programa que diz se um numero é par ou impar

num = int(input("Digite um número: "))

if ((num % 2) == 0):
  print("e par")
else:
  print("e impar")

# %%
# Programa que verifica se um número é par e menor que 10 ou se é impar ou se é só par

num = int(input("Digite um número: "))

if ((num % 2) == 0 and num < 10):
  print("e par e menor que 10")
elif (not (num % 2) == 0):
  print("e impar")
else:
  print("e so par")
# Out:
# Digite um número: 2
# e par e menor que 10

# %% [markdown]
# 1 - Faça um programa que recebe como entrada dois números inteiros e imprime como saída o maior entre eles. Caso sejam iguais imprima  "são iguais'.
#
# **EXEMPLO DE ENTRADA**
#
# 10
#
# 5
#
# **EXEMPLO DE SAÍDA**
#
# O maior número é 10

# %% [markdown]
# 2 - Faça um programa que lê uma letra, se for “M” imprima “Masculino, se for “F”
# imprima “Feminino”, senão imprima “Sexo invalido”.
#
# **EXEMPLO DE ENTRADA**
#
# M
#
# **EXEMPLO DE SAÍDA**
#
# Masculino

# %% [markdown]
# 3 - Faça um programa que recebe como entrada a **altura** e a **peso** de uma pessoa, como saída imprima qual a faixa de peso de acordo com o cálculo do **IMC**.
#
# **Informações:**
#
# O cálculo do IMC deve ser feito usando a seguinte fórmula matemática: Peso ÷ altura x altura.
#
# As faixas de acordo com o valor do IMC são:
#
# ![Faixas de peso](https://static.tuasaude.com/media/article/wm/sw/imc_32342_l.jpg)
#
#
# **EXEMPLO DE ENTRADA**
#
#
# 1.65
#
#
# 50
#
# **EXEMPLO DE SAÍDA**
#
# Abaixo do peso

# %% [markdown]
# 4 - Faça um programa que recebe com entrada o valor da compra e a  forma de pagamento, caso seja "D" de dinheiro apenas imprima o valor da compra. Caso seja "P" de parcelado pergunte ao usuário a quantidade de parcelas e como saída imprima o valor da  parcela.
#
#
#
# **EXEMPLO DE ENTRADA**
#
# 100.0
#
# D
#
# **EXEMPLO DE SAÍDA**
#
# Valor a pagar 100.0

# %% [markdown]
# 5 - Faça um programa que verifica se um aluno pode ser monitor ou não de uma matéria. Para que ele seja aprovado ele deve ter tido uma nota final na matéria maior ou igual a 8.0 e deve ter o coeficiente de rendimento maior ou igual a 5.0. Caso ele siga os critérios o programa deve imprimir "APROVADO", caso não, deve imprimir "REPROVADO".
#
# **ENTRADA**
#
# 8.5
#
# 5.8
#
# **SAÍDA**
#
# APROVADO
#
# ----------------------------
#
# **ENTRADA**
#
# 7.8
# 4.9
#
# **SAÍDA**
#
# REPROVADO
